# %% [markdown]
# **User Registration and Authentication**
# - No input field for referral code when signing up.
# - For the email verification, I received the mail but it seems it refused to verify because when I tried changing the status of phone, it kept showing error.

# %% [markdown]
# ![Screenshot_2025-10-21-15-52-09-814_com.android.chrome.jpg](attachment:Screenshot_2025-10-21-15-52-09-814_com.android.chrome.jpg)

# %% [markdown]
# **Phone Update Status**
# - Couldn't update the status from `active` to either `stolen` or `lost`. Showing email verification error, of which the email verification has been done earlier.

# %% [markdown]
# ![Screenshot_2025-10-21-20-32-04-391_com.android.chrome.jpg](attachment:Screenshot_2025-10-21-20-32-04-391_com.android.chrome.jpg)

# %% [markdown]
# **Phone Transfer Status**
# - The transfer button is not activated.
# - For phone transfer option, I don't seems to understand what it does and kept getting error.

# %% [markdown]
# ![Screenshot_2025-10-21-20-43-50-062_com.android.chrome.jpg](attachment:Screenshot_2025-10-21-20-43-50-062_com.android.chrome.jpg)
#
#
# ![Screenshot_2025-10-21-20-42-37-169_com.android.chrome.jpg](attachment:Screenshot_2025-10-21-20-42-37-169_com.android.chrome.jpg)

# %% [markdown]
# **Referral System**
# - No option to input the referral code when creating new account.
# - So, the workflow for that can't be tested.

# %% [markdown]
# ![Screenshot_2025-10-22-09-27-53-424_com.android.chrome.jpg](attachment:Screenshot_2025-10-22-09-27-53-424_com.android.chrome.jpg)

# %% [markdown]
# **Profile Update**
# - For the forget password: No `eye` icon, to show and verify what I typed.
# - I also got an error showing `PUT/...` as I couldn't screenshot it before the alert timestamp elapsed.
# - Profile updates is not going through as well.

# %% [markdown]
# Email verification required persist even after doing so

# %% [markdown]
# ![Screenshot_2025-10-21-20-37-29-767_com.android.chrome.jpg](attachment:Screenshot_2025-10-21-20-37-29-767_com.android.chrome.jpg)
